# %% [markdown]
# # Безусловная оптимизация (визуализация)

# %%
import numpy as np
import plotly.graph_objects as go

# %% [markdown]
# ## Пример 1
# Рассморим функцию $x^2+4y^2-2x-4y+10$

# %%
# Визуализация
# Making grid
x = np.linspace(-8, 9, 100)
y = np.linspace(-6, 7, 100)
X, Y = np.meshgrid(x, y)
Z = X**2+4*Y**2-2*X-4*Y+10

fig = go.Figure(data=[go.Surface(x=X, y=Y, z=Z)])
fig.show()

# %%
fig = go.Figure(data=go.Contour(
	x=x,	# Координаты по оси X
	y=x,	# Координаты по оси Y
	z=Z		# Значения функции (2D-массив)
))

fig.show()

# %% [markdown]
# ## Пример 2
# Рассморим функцию $10+2x-2y-4x^2-y^2+2xy$

# %%
# Визуализация
# Making grid
x = np.arange(start=-20, stop=20, step=0.2)
y = np.arange(start=-20, stop=20, step=0.2)
X, Y = np.meshgrid(x, y)
Z = 10+2*X-2*Y-4*X**2-Y**2+2*X*Y

fig = go.Figure(data=[go.Surface(x=X, y=Y, z=Z)])
fig.show()

# %%
fig = go.Figure(data=go.Contour(
	x=x,	# Координаты по оси X
	y=x,	# Координаты по оси Y
	z=Z		# Значения функции (2D-массив)
))

fig.show()

# %% [markdown]
# ## Пример 3
# Рассморим функцию $10+2x-2y-4x^2-y^2+8xy$

# %%
# Визуализация
# Making grid
x = np.arange(start=-20, stop=20, step=0.2)
y = np.arange(start=-20, stop=20, step=0.2)
X, Y = np.meshgrid(x, y)
Z = 10+2*X-2*Y-4*X**2-Y**2+8*X*Y

fig = go.Figure(data=[go.Surface(x=X, y=Y, z=Z)])
fig.show()

# %%
fig = go.Figure(data=go.Contour(
	x=x,	# Координаты по оси X
	y=x,	# Координаты по оси Y
	z=Z		# Значения функции (2D-массив)
))

fig.show()

# %% [markdown]
# ## Пример 4
# Рассморим функцию $x^3+x^2y-2y^3+6y$

# %%
# Визуализация
# Making grid
x = np.arange(start=-4, stop=4, step=0.1)
y = np.arange(start=-4, stop=4, step=0.1)
X, Y = np.meshgrid(x, y)
Z = X**3+X**2*Y-2*Y**3+6*Y

fig = go.Figure(data=[go.Surface(x=X, y=Y, z=Z)])
fig.show()

# %%
fig = go.Figure(data=go.Contour(
	x=x,	# Координаты по оси X
	y=x,	# Координаты по оси Y
	z=Z		# Значения функции (2D-массив)
))

fig.show()
